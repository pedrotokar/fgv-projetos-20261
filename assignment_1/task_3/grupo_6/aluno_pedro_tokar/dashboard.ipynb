# %% [markdown]
# # 1. Imports

# %%
# Só execute essa célula no SageMaker
# !pip install "seaborn" "awswrangler" "ipywidgets"

# %%
# Para analytics
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# Para conexão com AWS
import awswrangler as wr
import boto3
import os

# %% [markdown]
# # Setup da conexão com o Athena
#
# O notebook precisa apenas do nome dos recursos para acessar eles, já que na execução local o boto3 consegue ler as credenciais do arquivo ~/.aws/credentials e na execução do sagemaker o ambiente já é preparado e o notebook já tem acesso direto aos recursos.
#
# Se um nome diferente do padrão for utilizado, será necessário mudar isso nas variáveis de ambiente. Mas esses dados não são sensíveis, então é razoável deixar eles mais fixos.

# %%
GLUE_DATABASE = os.getenv("GLUE_DATABASE", "classicmodels_analytics")
ATHENA_WORKGROUP = os.getenv("ATHENA_WORKGROUP", "analytics_workgroup")

print(f"Usando o banco: {GLUE_DATABASE}")
print(f"Usando o workgroup: {ATHENA_WORKGROUP}")
# Out:
# Usando o banco: classicmodels_analytics
# Usando o workgroup: analytics_workgroup

# %% [markdown]
# Essa célula testa a conexão e já faz o teste especificado na sessão "4.2 - Consulta exploratória em dimensão"

# %%
session = boto3.Session(region_name="us-east-1")

query_teste = """
    SELECT
        product_id,
        product_name,
        product_line,
        product_vendor
    FROM dim_products
    LIMIT 20
"""

query_kwargs = {
    "database": GLUE_DATABASE,
    "boto3_session": session,
    "workgroup": ATHENA_WORKGROUP
}

df_produtos = wr.athena.read_sql_query(
    sql = query_teste,
    **query_kwargs
)

df_produtos.head()
# Out:
#   product_id               product_name      product_line  \
# 0   S18_3029     1999 Yamaha Speed Boat             Ships
# 1   S12_4473          1957 Chevy Pickup  Trucks and Buses
# 2   S24_4278    1900s Vintage Tri-Plane            Planes
# 3   S10_1949   1952 Alpine Renault 1300      Classic Cars
# 4   S24_3420  1937 Horch 930V Limousine      Vintage Cars
#
#             product_vendor
# 0          Min Lin Diecast
# 1            Exoto Designs
# 2     Unimax Art Galleries
# 3  Classic Metal Creations
# 4    Autoart Studio Design

# %% [markdown]
# # Análises

# %% [markdown]
# ## Vendas totais por país

# %%
query_vendas_pais = """
SELECT
    dim_countries.country,
    SUM(fact_orders.sales_amount) AS total_sales
FROM fact_orders
JOIN dim_countries ON fact_orders.country_key = dim_countries.country_key
GROUP BY dim_countries.country
ORDER BY total_sales DESC
LIMIT 10
"""

df_vendas = wr.athena.read_sql_query(
    sql = query_vendas_pais,
    **query_kwargs
)

df_vendas
# Out:
#        country total_sales
# 0          USA  3273280.05
# 1        Spain  1099389.09
# 2       France  1007374.02
# 3    Australia   562582.59
# 4  New Zealand   476847.01
# 5           UK   436947.44
# 6        Italy   360616.81
# 7      Finland   295149.35
# 8    Singapore   263997.78
# 9      Denmark   218994.92

# %% [markdown]
# ### Detalhes por data, linha de produto, produto e país

# %%
query_detalhes = """
SELECT
    dim_dates.full_date,
    dim_products.product_line,
    dim_products.product_name,
    dim_countries.country,
    SUM(fact_orders.sales_amount) AS total_sales
FROM fact_orders
JOIN dim_products ON fact_orders.product_id = dim_products.product_id
JOIN dim_countries ON fact_orders.country_key = dim_countries.country_key
JOIN dim_dates ON fact_orders.order_date_key = dim_dates.date_key
GROUP BY
    dim_dates.full_date,
    dim_products.product_line,
    dim_products.product_name,
    dim_countries.country
"""

df_detalhes = wr.athena.read_sql_query(
    sql = query_detalhes,
    **query_kwargs
)
df_detalhes["full_date"] = pd.to_datetime(df_detalhes["full_date"])
df_detalhes
# Out:
#       full_date  product_line                             product_name  \
# 0    2003-01-09  Vintage Cars                1932 Model A Ford J-Coupe
# 1    2003-01-09  Vintage Cars              1939 Chevrolet Deluxe Coupe
# 2    2004-03-15  Classic Cars                       1969 Corvair Monza
# 3    2004-03-15        Trains           1962 City of Detroit Streetcar
# 4    2004-03-15        Trains   1950's Chicago Surface Lines Streetcar
# ...         ...           ...                                      ...
# 2991 2004-12-16  Vintage Cars  1941 Chevrolet Special Deluxe Cabriolet
# 2992 2004-12-16         Ships                           The Queen Mary
# 2993 2004-12-16  Vintage Cars         1912 Ford Model T Delivery Wagon
# 2994 2004-12-16        Trains                 Collectable Wooden Train
# 2995 2005-04-01   Motorcycles                    1996 Moto Guzzi 1100i
#
#           country total_sales
# 0         Germany     2701.50
# 1         Germany     1463.85
# 2         Germany     5522.06
# 3         Germany     2468.63
# 4         Germany     2715.38
# ...           ...         ...
# 2991  New Zealand     4065.60
# 2992  New Zealand     2863.16
# 2993  New Zealand     2549.16
# 2994  New Zealand     2748.91
# 2995  New Zealand     5095.41
#
# [2996 rows x 5 columns]

# %% [markdown]
# ## Dashboard

# %%
data_min = df_detalhes["full_date"].min().date()
data_max = df_detalhes["full_date"].max().date()

# Listas com as opções que vão para os seletores do dashboard
paises = ["Todos"] + sorted(df_detalhes["country"].dropna().unique().tolist())
linhas_produto = ["Todos"] + sorted(df_detalhes["product_line"].dropna().unique().tolist())

# Declaracao dos Widgets que farão parte do dashboard
data_inicio = widgets.DatePicker(description="Data Inicial:", value=data_min)
data_fim = widgets.DatePicker(description="Data Final:", value=data_max)
dropdown_pais = widgets.Dropdown(options=paises, value="Todos", description="Pais:")
dropdown_linha = widgets.Dropdown(options=linhas_produto, value="Todos", description="Linha:")
slider_topn = widgets.IntSlider(value=5, min=1, max=10, description="Top N:")

# Essa função usa os inputs obtidos pelos widgets para gerar o gráfico de top N
def atualizar_dashboard(pais, linha, data_ini, data_f, top_n):
    df_filtrado = df_detalhes.copy()
    
    ts_ini = pd.to_datetime(data_ini)
    ts_f = pd.to_datetime(data_f)
    df_filtrado = df_filtrado[(df_filtrado["full_date"] >= ts_ini) & (df_filtrado["full_date"] <= ts_f)]
    
    # Aplica os filtros dos widgets
    if pais != "Todos":
        df_filtrado = df_filtrado[df_filtrado["country"] == pais]
        
    if linha != "Todos":
        df_filtrado = df_filtrado[df_filtrado["product_line"] == linha]
        
    # Caso de borda em que não há dados de venda
    if df_filtrado.empty:
        print("Nenhum dado encontrado para os filtros selecionados no intervalo de datas.")
        return

    df_agrupado = df_filtrado.groupby("product_name", as_index=False)["total_sales"].sum()
    df_top_n = df_agrupado.sort_values(by="total_sales", ascending=False).head(top_n)
    
    # Configuração do gráfico com o seaborn
    plt.figure(figsize=(10, 6))
    sns.barplot(data=df_top_n, x="total_sales", y="product_name", hue="product_name", palette="viridis")
    
    plt.title(f"Top {top_n} Produtos Vendidos")
    plt.xlabel("Vendas Totais ($)")
    plt.ylabel("Nome do Produto")    
    plt.tight_layout()
    plt.show()

# Organiza os botoes
ui_filtros = widgets.VBox([
    widgets.HBox([data_inicio, data_fim]),
    widgets.HBox([dropdown_pais, dropdown_linha]),
    slider_topn
])

# Conecta os widgets com a funcao de plotagem
out = widgets.interactive_output(atualizar_dashboard, {
    "pais": dropdown_pais,
    "linha": dropdown_linha,
    "data_ini": data_inicio,
    "data_f": data_fim,
    "top_n": slider_topn
})

# Renderiza tudo na celula do Jupyter
display(ui_filtros, out)
# Out:
# VBox(children=(HBox(children=(DatePicker(value=datetime.date(2003, 1, 6), description='Data Inicial:', step=1)…
# Output()
